# %%
import os
import glob
import time
import re
import shutil
from os import listdir, makedirs
from os.path import isfile, join
import matplotlib.pyplot as plt
from tabulate import tabulate

start_time = time.time()
import cv2

print("How many images you want to convert:- 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000")
val = int(input("Enter value"))

if val == 1000:
    #print("If number of images are 1000")
    for i in range(1000):
        shutil.copyfile("/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time1 = time.time() - start_time
    print("time1k=",time1,"s")

elif val == 2000:

    print("If number of images are 2000")
    for i in range(2000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time2 = time.time() - start_time
    print("time2k=", time2, "s")

elif val == 3000:

    print("If number of images are 3000")
    for i in range(3000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time3 = time.time() - start_time
    print("time3k=", time3, "s")

elif val == 4000:

    print("If number of images are 4000")
    for i in range(4000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time4 = time.time() - start_time

    print("time4k=", time4, "s")

elif val == 5000:
    print("If number of images are 5000")
    for i in range(5000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time5 = time.time() - start_time

    print("time5k=", time5, "s")

elif val == 6000:
    print("If number of images are 6000")
    for i in range(6000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time6 = time.time() - start_time
    print("time6k=", time6, "s")

elif val == 7000:
    print("If number of images are 7000")
    for i in range(7000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time7 = time.time() - start_time

    print("time7k=", time7, "s")

elif val == 8000:
    print("If number of images are 8000")
    for i in range(8000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time8 = time.time() - start_time
    print("time8k=", time8, "s")

elif val == 9000:
    print("If number of images are 9000")
    for i in range(9000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time9 = time.time() - start_time

    print("time9k=", time9, "s")

elif val == 10000:
    print("If number of images are 10000")
    for i in range(10000):
        shutil.copyfile(
            "/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/image.jpeg",
            dst=f"/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs/img{i}.jpeg")

    path = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/copied_imgs'  # Source Folder
    dstpath = '/Users/vatsalnanda/Desktop/Research Interns and Papers/prashant_singh_rana_sir/mini_proj_2/dst_img'  # Destination Folder

    # try:
    #     makedirs(dstpath)
    # except:
    #     print ("Directory already exist, images will be written in asme folder")

    # Folder won't used

    files = [f for f in listdir(path) if isfile(join(path, f))]
    x = len(os.listdir(dstpath))

    for image in files:
        try:

            img = cv2.imread(os.path.join(path, image))
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            dstPath = join(dstpath, image)

            cv2.imwrite(dstPath, gray)

        except:
            print("{} is not converted".format(image))

    time10 = time.time() - start_time
    print("time10k=", time10, "s")
# Out:
# How many images you want to convert:- 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000
# Enter value10000
# If number of images are 10000
# .DS_Store is not converted
# time10k= 98.81460404396057 s

# %%
from tabulate import tabulate



x=["1000","2000","3000","4000","5000","6000","7000","8000","9000","10000"]

y=[time1,time2,time3,time4,time5,time6,time7,time8,time9,time10]
plt.plot(x,y)

plt.xlabel("Number of images")

plt.ylabel("Time taken in seconds")

l = [["1000",time1],["2000",time2], ["3000",time3], ["4000",time4] , ["5000",time5],["6000",time6],["7000",time7],["8000",time8],["9000",time9],["10000",time10]]
table = tabulate(l, headers=['Number of images', 'Time taken in seconds'], tablefmt='orgtbl')

print(table)
# Out:
# |   Number of images |   Time taken in seconds |
# |--------------------+-------------------------|
# |               1000 |                 25.1262 |
# |               2000 |                 21.6669 |
# |               3000 |                 34.6331 |
# |               4000 |                 36.915  |
# |               5000 |                 55.0564 |
# |               6000 |                 58.502  |
# |               7000 |                 70.1244 |
# |               8000 |                 78.0997 |
# |               9000 |                 87.1734 |
# |              10000 |                 98.8146 |

# %%
plt.scatter(x,y)

plt.xlabel("Number of images")

plt.ylabel("Time taken in seconds")
# Out:
# Text(0, 0.5, 'Time taken in seconds')
